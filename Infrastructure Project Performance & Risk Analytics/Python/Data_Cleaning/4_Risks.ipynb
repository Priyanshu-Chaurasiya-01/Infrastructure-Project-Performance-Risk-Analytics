# %% [markdown]
# **Risks**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from pathlib import Path

# %%
file_path = Path.cwd().parent.parent/"Excel"/"4_Risks.xlsx"
df = pd.read_excel(file_path)
df
# Out:
#     Risk_ID Project_ID         Risk_Type Probability    Impact Risk_Status
# 0     R9001      P1001        Regulatory         Low       Low        Open
# 1     R9002      P1002     Environmental   Very High       Low      Closed
# 2     R9003      P1002  Land Acquisition         Low  Critical      Closed
# 3     R9004      P1002         Financial   Very High       Low  Monitoring
# 4     R9005      P1002          Schedule   Very High      High   Mitigated
# ..      ...        ...               ...         ...       ...         ...
# 691   R9692      P1115        Regulatory      Medium       Low      Closed
# 692   R9693      P1235          Schedule      Medium       Low      Closed
# 693   R9694      P1195     Environmental   Very High    Medium   Mitigated
# 694   R9695      P1098        Regulatory   Very High       Low   Mitigated
# 695   R9696      P1127            Safety         NaN       Low      Closed
#
# [696 rows x 6 columns]

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Risk_ID      696 non-null    object
#  1   Project_ID   686 non-null    object
#  2   Risk_Type    686 non-null    object
#  3   Probability  685 non-null    object
#  4   Impact       688 non-null    object
#  5   Risk_Status  686 non-null    object
# dtypes: object(6)
# memory usage: 32.8+ KB

# %%
df.drop_duplicates(subset=["Risk_ID"], inplace=True)
df["Project_ID"] = df["Project_ID"].ffill()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Risk_ID      696 non-null    object
#  1   Project_ID   696 non-null    object
#  2   Risk_Type    686 non-null    object
#  3   Probability  685 non-null    object
#  4   Impact       688 non-null    object
#  5   Risk_Status  686 non-null    object
# dtypes: object(6)
# memory usage: 32.8+ KB

# %%
df.to_csv("../../Data/Cleaned/Risks.csv", index=False)
